# %% [markdown]
# # **eRosita Data Analysis Workflow**
#
# Contact: tarjar.bunke-risstad\<at\>student.uni-tuebingen.de

# %% [markdown]
# Download the slides from: [link](https://drive.google.com/file/d/1eNhFbg3w-nOoU47WkhVzmGnxEaIPa6yp/view?usp=sharing)

# %% [markdown]
# <!-- ```{pdf} ../_static/eROSITA_example.pdf
# :width: 100%
# :height: 900px
# :align: center -->

# %%
# from IPython.display import IFrame
# IFrame('../_static/eROSITA_example.pdf', width=900, height=700)

# %% [markdown]
# <!-- ```{raw} html
# <object data="../_static/eROSITA_example.pdf" type="application/pdf" width="100%" height="800px">
#     <p>Your browser does not support embedded PDFs.
#        <a href="../_static/eROSITA_example.pdf">Download the PDF</a>.</p>
# </object> -->
